# %%
import xmlrpc.client as xrpc

server = xrpc.ServerProxy("http://api.opensubtitles.org/xml-rpc")

# %%
server.ServerInfo()

credentials = server.LogIn("", "", "en", "OSTestUserAgentTemp")
token = credentials.get("token")

# %%
# server.GetSubLanguages()
# server.SearchMoviesOnIMDB(token, "troy")
server.SearchSubtitles(token, [{'imdbid': '1515091', 'sublanguageid': 'eng'}])
# Out:
# {'data': [{'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '4474095',
#    'IDSubtitleFile': '1953036639',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '25.000',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': 'Harks Re-Encode x264 Updated Complete',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '1',
#    'SubAddDate': '2012-02-20 11:21:34',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '0',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-19a30c56/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1953036639.gz',
#    'SubDownloadsCnt': '21273',
#    'SubEncoding': 'UTF-8',
#    'SubFeatured': '0',
#    'SubFileName': 'sherlock holmes II.srt',
#    'SubFormat': 'srt',
#    'SubHD': '0',
#    'SubHash': '2adafc290f91c8825ad6f19fb5edc72d',
#    'SubHearingImpaired': '0',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '01:59:01',
#    'SubRating': '0.0',
#    'SubSize': '102667',
#    'SubSumCD': '1',
#    'SubTSGroup': '3',
#    'SubTSGroupHash': 'd3617a1fc8e35a67ba1b340f295354f1',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/4474095/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '1399919',
#    'UserNickName': 'Fisticuffs',
#    'UserRank': 'bronze member',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f5470bba/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/4474095'},
#   {'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '4535061',
#    'IDSubtitleFile': '1953101239',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '23.976',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': 'BluRay.1080p.DTS.x264-CHD',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '1',
#    'SubAddDate': '2012-04-30 17:28:35',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '0',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-197a0c4b/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1953101239.gz',
#    'SubDownloadsCnt': '17713',
#    'SubEncoding': 'CP850',
#    'SubFeatured': '0',
#    'SubFileName': 'Sherlock.Holmes.A.Game.of.Shadows.2011.BluRay.1080p.DTS.x264-CHD.eng.srt',
#    'SubFormat': 'srt',
#    'SubHD': '1',
#    'SubHash': 'd79b2518cceddf525c0c58d92f4735e7',
#    'SubHearingImpaired': '1',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '02:00:00',
#    'SubRating': '0.0',
#    'SubSize': '93636',
#    'SubSumCD': '1',
#    'SubTSGroup': '1',
#    'SubTSGroupHash': 'ee82ed982aebf63a54d7cf0c5f1eccc8',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/4535061/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '1295723',
#    'UserNickName': 'deep_sea',
#    'UserRank': 'trusted',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f5330bb1/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/4535061'},
#   {'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '4533342',
#    'IDSubtitleFile': '1953099467',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '23.976',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': '720p.BluRay.x264.DTS-WiKi',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '1',
#    'SubAddDate': '2012-04-28 18:39:36',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '0',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-19cb0c5e/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1953099467.gz',
#    'SubDownloadsCnt': '9437',
#    'SubEncoding': 'UTF-8',
#    'SubFeatured': '0',
#    'SubFileName': 'Sherlock.Holmes.A.Game.of.Shadows.2011.720p.BluRay.x264.DTS-WiKi.eng.srt',
#    'SubFormat': 'srt',
#    'SubHD': '1',
#    'SubHash': '5718ba7fe09fd8d49cb7df2ffe4f26d8',
#    'SubHearingImpaired': '0',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '01:59:59',
#    'SubRating': '0.0',
#    'SubSize': '91176',
#    'SubSumCD': '1',
#    'SubTSGroup': '1',
#    'SubTSGroupHash': 'ee82ed982aebf63a54d7cf0c5f1eccc8',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/4533342/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '969697',
#    'UserNickName': 'spaceboy74',
#    'UserRank': 'trusted',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f5310bb1/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/4533342'},
#   {'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '4533258',
#    'IDSubtitleFile': '1953099345',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '23.976',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': 'Sherlock Holmes - A Game Of Shadows (2011)',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '1',
#    'SubAddDate': '2012-04-28 16:21:02',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '0',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-19c20c59/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1953099345.gz',
#    'SubDownloadsCnt': '11587',
#    'SubEncoding': 'UTF-8',
#    'SubFeatured': '0',
#    'SubFileName': 'Sherlock Holmes - A Game Of Shadows (2011).en.srt',
#    'SubFormat': 'srt',
#    'SubHD': '0',
#    'SubHash': 'b3ea7090c645e3b8f5bcd2dbca85be2f',
#    'SubHearingImpaired': '0',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '02:00:00',
#    'SubRating': '0.0',
#    'SubSize': '90537',
#    'SubSumCD': '1',
#    'SubTSGroup': '1',
#    'SubTSGroupHash': 'ee82ed982aebf63a54d7cf0c5f1eccc8',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/4533258/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '322686',
#    'UserNickName': 'snoopyman',
#    'UserRank': 'platinum member',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f5360bb7/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/4533258'},
#   {'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '4526515',
#    'IDSubtitleFile': '1953092717',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '23.976',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': '1080p.BluRay.x264-UNVEiL',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '1',
#    'SubAddDate': '2012-04-22 18:30:43',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '0',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-19ae0c55/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1953092717.gz',
#    'SubDownloadsCnt': '5280',
#    'SubEncoding': 'UTF-8',
#    'SubFeatured': '0',
#    'SubFileName': 'sherlock.holmes.a.game.of.shadows.2011.1080p.bluray.x264-unveil.srt',
#    'SubFormat': 'srt',
#    'SubHD': '1',
#    'SubHash': '6a529c9989e6e9d8477c9b0189ff0333',
#    'SubHearingImpaired': '0',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '02:00:00',
#    'SubRating': '0.0',
#    'SubSize': '90643',
#    'SubSumCD': '1',
#    'SubTSGroup': '1',
#    'SubTSGroupHash': 'ee82ed982aebf63a54d7cf0c5f1eccc8',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/4526515/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '0',
#    'UserNickName': '',
#    'UserRank': '',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f53b0bb5/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/4526515'},
#   {'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '4524042',
#    'IDSubtitleFile': '1953090356',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '23.976',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': '1080p.BluRay.x264-UNVEiL',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '1',
#    'SubAddDate': '2012-04-20 19:05:32',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '0',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-19a10c52/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1953090356.gz',
#    'SubDownloadsCnt': '6077',
#    'SubEncoding': 'UTF-8',
#    'SubFeatured': '0',
#    'SubFileName': 'sherlock.holmes.a.game.of.shadows.2011.1080p.bluray.x264-unveil.srt',
#    'SubFormat': 'srt',
#    'SubHD': '1',
#    'SubHash': 'fa62d73a825bbc19dab61910bb2e443a',
#    'SubHearingImpaired': '0',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '02:00:07',
#    'SubRating': '0.0',
#    'SubSize': '103441',
#    'SubSumCD': '1',
#    'SubTSGroup': '1',
#    'SubTSGroupHash': 'ee82ed982aebf63a54d7cf0c5f1eccc8',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/4524042/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '0',
#    'UserNickName': '',
#    'UserRank': '',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f5270bae/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/4524042'},
#   {'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '4521966',
#    'IDSubtitleFile': '1953088304',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '23.976',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': 'Blu-Ray.1080p.AVC.DTS-HD.MA.5.1-HDChina',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '1',
#    'SubAddDate': '2012-04-18 23:01:09',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '1',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-19b00c52/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1953088304.gz',
#    'SubDownloadsCnt': '7659',
#    'SubEncoding': 'UTF-8',
#    'SubFeatured': '0',
#    'SubFileName': 'Sherlock.Holmes.A.Game.of.Shadows.2011.1080p.Blu-ray.AVC.DTS-HD.MA.5.1-HDChina.english.srt',
#    'SubFormat': 'srt',
#    'SubHD': '1',
#    'SubHash': '1410617ad3990a07f301a274c299f134',
#    'SubHearingImpaired': '0',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '02:00:00',
#    'SubRating': '8.5',
#    'SubSize': '91126',
#    'SubSumCD': '1',
#    'SubTSGroup': '1',
#    'SubTSGroupHash': 'ee82ed982aebf63a54d7cf0c5f1eccc8',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/4521966/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '847082',
#    'UserNickName': 'cipry',
#    'UserRank': 'trusted',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f53e0bba/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/4521966'},
#   {'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '4521960',
#    'IDSubtitleFile': '1953088298',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '23.976',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': 'Blu-Ray.1080p.AVC.DTS-HD.MA.5.1-HDChina',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '1',
#    'SubAddDate': '2012-04-18 22:56:05',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '0',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-19c30c5e/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1953088298.gz',
#    'SubDownloadsCnt': '13023',
#    'SubEncoding': 'UTF-8',
#    'SubFeatured': '0',
#    'SubFileName': 'Sherlock.Holmes.A.Game.of.Shadows.2011.1080p.Blu-ray.AVC.DTS-HD.MA.5.1-HDChina.english.srt',
#    'SubFormat': 'srt',
#    'SubHD': '1',
#    'SubHash': '94aad9f575512c9911350d8ed186ed05',
#    'SubHearingImpaired': '1',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '02:08:40',
#    'SubRating': '0.0',
#    'SubSize': '107797',
#    'SubSumCD': '1',
#    'SubTSGroup': '1',
#    'SubTSGroupHash': 'ee82ed982aebf63a54d7cf0c5f1eccc8',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/4521960/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '847082',
#    'UserNickName': 'cipry',
#    'UserRank': 'trusted',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f5380bb4/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/4521960'},
#   {'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '4521726',
#    'IDSubtitleFile': '1953088049',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '23.976',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': 'Bluray.No.tags',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '1',
#    'SubAddDate': '2012-04-18 18:18:08',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '0',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-19b40c58/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1953088049.gz',
#    'SubDownloadsCnt': '2361',
#    'SubEncoding': 'CP1252',
#    'SubFeatured': '0',
#    'SubFileName': 'Sherlock.Holmes.A.Game.of.Shadows.2011.Bluray.english.srt',
#    'SubFormat': 'srt',
#    'SubHD': '1',
#    'SubHash': '99c0fa78067e057c4175b748417558fe',
#    'SubHearingImpaired': '0',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '02:08:40',
#    'SubRating': '0.0',
#    'SubSize': '91119',
#    'SubSumCD': '1',
#    'SubTSGroup': '1',
#    'SubTSGroupHash': 'ee82ed982aebf63a54d7cf0c5f1eccc8',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/4521726/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '0',
#    'UserNickName': '',
#    'UserRank': '',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f5300bb4/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/4521726'},
#   {'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '4521725',
#    'IDSubtitleFile': '1953088048',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '23.976',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': 'Bluray.Original.SDH',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '1',
#    'SubAddDate': '2012-04-18 18:18:02',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '0',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-19b30c57/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1953088048.gz',
#    'SubDownloadsCnt': '1775',
#    'SubEncoding': 'CP1252',
#    'SubFeatured': '0',
#    'SubFileName': 'Sherlock.Holmes.A.Game.of.Shadows.2011.Bluray.english-sdh.srt',
#    'SubFormat': 'srt',
#    'SubHD': '1',
#    'SubHash': 'e4d9d41483d27b4707d32680a1ea71db',
#    'SubHearingImpaired': '1',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '02:08:40',
#    'SubRating': '0.0',
#    'SubSize': '107724',
#    'SubSumCD': '1',
#    'SubTSGroup': '1',
#    'SubTSGroupHash': 'ee82ed982aebf63a54d7cf0c5f1eccc8',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/4521725/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '0',
#    'UserNickName': '',
#    'UserRank': '',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f52f0bb3/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/4521725'},
#   {'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '4521304',
#    'IDSubtitleFile': '1953087555',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '23.976',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': '1080p.BluRay.x264-RSG',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '1',
#    'SubAddDate': '2012-04-18 00:27:24',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '0',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-19bd0c59/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1953087555.gz',
#    'SubDownloadsCnt': '15470',
#    'SubEncoding': 'UTF-8',
#    'SubFeatured': '0',
#    'SubFileName': 'Sherlock.Holmes.A.Game.of.Shadows.2011.1080p.BluRay.x264-RSG.english.srt',
#    'SubFormat': 'srt',
#    'SubHD': '1',
#    'SubHash': '4d0005a3b36ec4e490374e1fdc4d446a',
#    'SubHearingImpaired': '1',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '02:08:37',
#    'SubRating': '0.0',
#    'SubSize': '107906',
#    'SubSumCD': '1',
#    'SubTSGroup': '1',
#    'SubTSGroupHash': 'ee82ed982aebf63a54d7cf0c5f1eccc8',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/4521304/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '2283448',
#    'UserNickName': 'gene2',
#    'UserRank': 'gold member',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f51e0bac/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/4521304'},
#   {'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '4520033',
#    'IDSubtitleFile': '1953086288',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '23.976',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': '720p.BRRIP.XVID.AC3-RemixHD',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '1',
#    'SubAddDate': '2012-04-16 20:32:10',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '0',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-19b90c5b/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1953086288.gz',
#    'SubDownloadsCnt': '5797',
#    'SubEncoding': 'GB18030',
#    'SubFeatured': '0',
#    'SubFileName': 'Sherlock.Holmes.A.Game.Of.Shadows.2011.720p.BRRIP.XVID.AC3-RemixHD.srt',
#    'SubFormat': 'srt',
#    'SubHD': '1',
#    'SubHash': 'd826164877e2df5ae4dcb7d1d239fb78',
#    'SubHearingImpaired': '0',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '02:00:00',
#    'SubRating': '0.0',
#    'SubSize': '90568',
#    'SubSumCD': '1',
#    'SubTSGroup': '1',
#    'SubTSGroupHash': 'ee82ed982aebf63a54d7cf0c5f1eccc8',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/4520033/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '0',
#    'UserNickName': '',
#    'UserRank': '',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f5160baa/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/4520033'},
#   {'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '4520002',
#    'IDSubtitleFile': '1953086244',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '23.976',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': '1080p.BluRay.x264-UNVEiL',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '1',
#    'SubAddDate': '2012-04-16 19:52:33',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '0',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-19ad0c53/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1953086244.gz',
#    'SubDownloadsCnt': '11583',
#    'SubEncoding': 'CP1252',
#    'SubFeatured': '0',
#    'SubFileName': 'sherlock.holmes.a.game.of.shadows.2011.1080p.bluray.x264-unveil.srt',
#    'SubFormat': 'srt',
#    'SubHD': '1',
#    'SubHash': '57367e19a68c529e95cc148a00395513',
#    'SubHearingImpaired': '1',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '02:00:09',
#    'SubRating': '0.0',
#    'SubSize': '107245',
#    'SubSumCD': '1',
#    'SubTSGroup': '1',
#    'SubTSGroupHash': 'ee82ed982aebf63a54d7cf0c5f1eccc8',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/4520002/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '0',
#    'UserNickName': '',
#    'UserRank': '',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f50f0ba6/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/4520002'},
#   {'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '4519779',
#    'IDSubtitleFile': '1953085985',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '23.976',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': 'BDRiP.XViD-AN0NYM0US',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '1',
#    'SubAddDate': '2012-04-16 13:12:47',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '0',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-19c70c5e/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1953085985.gz',
#    'SubDownloadsCnt': '3510',
#    'SubEncoding': 'CP1252',
#    'SubFeatured': '0',
#    'SubFileName': 'anony-sherlock2_cd1.srt',
#    'SubFormat': 'srt',
#    'SubHD': '1',
#    'SubHash': '5170cdc02b1c7cc06091f74bace941df',
#    'SubHearingImpaired': '0',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '01:04:53',
#    'SubRating': '0.0',
#    'SubSize': '53946',
#    'SubSumCD': '2',
#    'SubTSGroup': '14',
#    'SubTSGroupHash': '6fbc4e58a9e9e8bdb23f686945e1710c',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/4519779/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '1303060',
#    'UserNickName': 'kempelen21',
#    'UserRank': 'bronze member',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f5580bc3/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/4519779'},
#   {'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '4519779',
#    'IDSubtitleFile': '1953085986',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '23.976',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': 'BDRiP.XViD-AN0NYM0US',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '2',
#    'SubAddDate': '2012-04-16 13:12:47',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '0',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-19c80c5f/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1953085986.gz',
#    'SubDownloadsCnt': '3510',
#    'SubEncoding': 'CP1252',
#    'SubFeatured': '0',
#    'SubFileName': 'anony-sherlock2_cd2.srt',
#    'SubFormat': 'srt',
#    'SubHD': '1',
#    'SubHash': '4b8c473ddd0ccd8e78b2da4c1f4ad037',
#    'SubHearingImpaired': '0',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '00:54:41',
#    'SubRating': '0.0',
#    'SubSize': '36331',
#    'SubSumCD': '2',
#    'SubTSGroup': '14',
#    'SubTSGroupHash': '70eaa7ecd6d275597ea7eba65b64c67f',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/4519779/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '1303060',
#    'UserNickName': 'kempelen21',
#    'UserRank': 'bronze member',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f5580bc3/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/4519779'},
#   {'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '4519761',
#    'IDSubtitleFile': '1953085967',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '23.976',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': '720p.BRRip.XviD.AC3-ViSiON',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '1',
#    'SubAddDate': '2012-04-16 12:40:43',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '0',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-19c50c5e/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1953085967.gz',
#    'SubDownloadsCnt': '47564',
#    'SubEncoding': 'UTF-8',
#    'SubFeatured': '0',
#    'SubFileName': 'Sherlock.Holmes.A.Game.Of.Shadows.2011.720p.BRRip.XviD.AC3-ViSiON.srt',
#    'SubFormat': 'srt',
#    'SubHD': '1',
#    'SubHash': 'f3ad0e830501da7bc1c468a187c2bcc2',
#    'SubHearingImpaired': '0',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '01:59:59',
#    'SubRating': '0.0',
#    'SubSize': '91169',
#    'SubSumCD': '1',
#    'SubTSGroup': '1',
#    'SubTSGroupHash': 'ee82ed982aebf63a54d7cf0c5f1eccc8',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/4519761/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '0',
#    'UserNickName': '',
#    'UserRank': '',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f54e0bba/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/4519761'},
#   {'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '4519742',
#    'IDSubtitleFile': '1953085947',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '23.976',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': 'BluRay.x264.1080p.720p [and BRRip.XviD-KAZAN]',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '1',
#    'SubAddDate': '2012-04-16 12:05:37',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '0',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-19c10c5c/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1953085947.gz',
#    'SubDownloadsCnt': '5475',
#    'SubEncoding': 'UTF-8',
#    'SubFeatured': '0',
#    'SubFileName': 'Sherlock Holmes 2 A Game of Shadows 2011 BluRay Bdrip x264 1080p 720p.srt',
#    'SubFormat': 'srt',
#    'SubHD': '1',
#    'SubHash': '42c07498638ae0734cefafdb8ba22b8f',
#    'SubHearingImpaired': '0',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '02:00:00',
#    'SubRating': '0.0',
#    'SubSize': '90649',
#    'SubSumCD': '1',
#    'SubTSGroup': '1',
#    'SubTSGroupHash': 'ee82ed982aebf63a54d7cf0c5f1eccc8',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/4519742/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '0',
#    'UserNickName': '',
#    'UserRank': '',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f54b0bb9/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/4519742'},
#   {'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '4519741',
#    'IDSubtitleFile': '1953085946',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '23.976',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': 'BluRay.x264.1080p.720p [and BRRip.XviD-KAZAN]',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '1',
#    'SubAddDate': '2012-04-16 12:05:14',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '0',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-19c00c5b/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1953085946.gz',
#    'SubDownloadsCnt': '2926',
#    'SubEncoding': 'UTF-8',
#    'SubFeatured': '0',
#    'SubFileName': 'Sherlock Holmes 2 A Game of Shadows 2011 BluRay Bdrip x264 1080p 720p.Hi.srt',
#    'SubFormat': 'srt',
#    'SubHD': '1',
#    'SubHash': 'e8c76247b9dca05b37cebc70a1026d63',
#    'SubHearingImpaired': '1',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '02:00:08',
#    'SubRating': '0.0',
#    'SubSize': '106974',
#    'SubSumCD': '1',
#    'SubTSGroup': '1',
#    'SubTSGroupHash': 'ee82ed982aebf63a54d7cf0c5f1eccc8',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/4519741/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '0',
#    'UserNickName': '',
#    'UserRank': '',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f54a0bb8/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/4519741'},
#   {'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '4519736',
#    'IDSubtitleFile': '1953085941',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '23.976',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': '720p.BluRay.x264-SONS--Sherlock Holmes: A Game of Shadows',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '1',
#    'SubAddDate': '2012-04-16 11:56:07',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '0',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-19bb0c56/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1953085941.gz',
#    'SubDownloadsCnt': '27499',
#    'SubEncoding': 'UTF-8',
#    'SubFeatured': '0',
#    'SubFileName': '720p.BluRay.x264-SONS.srt',
#    'SubFormat': 'srt',
#    'SubHD': '1',
#    'SubHash': '6ba3966352cab29c0f5c0771721d9ef0',
#    'SubHearingImpaired': '0',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '02:00:00',
#    'SubRating': '10.0',
#    'SubSize': '90647',
#    'SubSumCD': '1',
#    'SubTSGroup': '1',
#    'SubTSGroupHash': 'ee82ed982aebf63a54d7cf0c5f1eccc8',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/4519736/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '1436527',
#    'UserNickName': 'aliyan',
#    'UserRank': 'gold member',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f54d0bbc/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/4519736'},
#   {'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '4519735',
#    'IDSubtitleFile': '1953085940',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '23.976',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': '720p.BluRay.x264-SONS--Sherlock Holmes: A Game of Shadows',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '1',
#    'SubAddDate': '2012-04-16 11:56:04',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '0',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-19ba0c55/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1953085940.gz',
#    'SubDownloadsCnt': '15359',
#    'SubEncoding': 'UTF-8',
#    'SubFeatured': '0',
#    'SubFileName': '720p.BluRay.x264-SONS.Hi.srt',
#    'SubFormat': 'srt',
#    'SubHD': '1',
#    'SubHash': '87e96713ed7e03fbbe58efbef82eb1d8',
#    'SubHearingImpaired': '1',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '02:00:08',
#    'SubRating': '0.0',
#    'SubSize': '106965',
#    'SubSumCD': '1',
#    'SubTSGroup': '1',
#    'SubTSGroupHash': 'ee82ed982aebf63a54d7cf0c5f1eccc8',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/4519735/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '0',
#    'UserNickName': '',
#    'UserRank': '',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f54c0bbb/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/4519735'},
#   {'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '4519671',
#    'IDSubtitleFile': '1953085867',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '23.976',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': '720p/1080p.BluRay.x264-RSG',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '1',
#    'SubAddDate': '2012-04-16 10:17:00',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '0',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-19c20c5d/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1953085867.gz',
#    'SubDownloadsCnt': '14403',
#    'SubEncoding': 'UTF-8',
#    'SubFeatured': '0',
#    'SubFileName': 'Sherlock.Holmes.A.Game.of.Shadows.2011.1080p.BluRay.x264-RSG.english.srt',
#    'SubFormat': 'srt',
#    'SubHD': '1',
#    'SubHash': 'f3983d4f4d7a08247c11fc926ff598da',
#    'SubHearingImpaired': '0',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '01:59:59',
#    'SubRating': '0.0',
#    'SubSize': '91172',
#    'SubSumCD': '1',
#    'SubTSGroup': '1',
#    'SubTSGroupHash': 'ee82ed982aebf63a54d7cf0c5f1eccc8',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/4519671/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '847082',
#    'UserNickName': 'cipry',
#    'UserRank': 'trusted',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f54d0bba/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/4519671'},
#   {'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '4519670',
#    'IDSubtitleFile': '1953085866',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '23.976',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': '720p/1080p.BluRay.x264-RSG',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '1',
#    'SubAddDate': '2012-04-16 10:15:58',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '1',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-19c10c5c/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1953085866.gz',
#    'SubDownloadsCnt': '17528',
#    'SubEncoding': 'UTF-8',
#    'SubFeatured': '0',
#    'SubFileName': 'Sherlock.Holmes.A.Game.of.Shadows.2011.1080p.BluRay.x264-RSG.english.srt',
#    'SubFormat': 'srt',
#    'SubHD': '1',
#    'SubHash': '3fa126f6cf2b8973036b225d684beee0',
#    'SubHearingImpaired': '1',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '02:08:37',
#    'SubRating': '0.0',
#    'SubSize': '107909',
#    'SubSumCD': '1',
#    'SubTSGroup': '1',
#    'SubTSGroupHash': 'ee82ed982aebf63a54d7cf0c5f1eccc8',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/4519670/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '847082',
#    'UserNickName': 'cipry',
#    'UserRank': 'trusted',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f54c0bb9/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/4519670'},
#   {'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '4515531',
#    'IDSubtitleFile': '1953081864',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '25.000',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': 'A.Game.of.Shadows.2011.R6 Rip.XviD-HOPE.nitro',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '1',
#    'SubAddDate': '2012-04-12 16:03:52',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '0',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-19af0c56/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1953081864.gz',
#    'SubDownloadsCnt': '4073',
#    'SubEncoding': 'Unknown',
#    'SubFeatured': '0',
#    'SubFileName': 'Sherlock Holmes 2 A Game Of Shadows 2011.srt',
#    'SubFormat': 'srt',
#    'SubHD': '0',
#    'SubHash': '85f2a1034d98d3899a014aea6cd9b1d3',
#    'SubHearingImpaired': '0',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '01:55:33',
#    'SubRating': '0.0',
#    'SubSize': '89663',
#    'SubSumCD': '1',
#    'SubTSGroup': '2',
#    'SubTSGroupHash': '814064fd4437ca5ff2c674d5d6ed70c6',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/4515531/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '0',
#    'UserNickName': '',
#    'UserRank': '',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f5320bb1/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/4515531'},
#   {'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '4514795',
#    'IDSubtitleFile': '1953081183',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '25.000',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': 'A.Game.of.Shadows.2011.R6Rip.XviD-HOPE',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '1',
#    'SubAddDate': '2012-04-12 10:43:38',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '0',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-199d0c50/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1953081183.gz',
#    'SubDownloadsCnt': '82029',
#    'SubEncoding': 'UTF-8',
#    'SubFeatured': '0',
#    'SubFileName': 'Sherlock.Holmes.2.A.Game.Of.Shadows.2011.R6Rip.XviD-HOPE.srt',
#    'SubFormat': 'srt',
#    'SubHD': '0',
#    'SubHash': '985d6496d65b2778c052d699bd9c9869',
#    'SubHearingImpaired': '0',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '01:55:24',
#    'SubRating': '8.5',
#    'SubSize': '92757',
#    'SubSumCD': '1',
#    'SubTSGroup': '2',
#    'SubTSGroupHash': '814064fd4437ca5ff2c674d5d6ed70c6',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/4514795/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '1173837',
#    'UserNickName': 'rameshmehra',
#    'UserRank': 'bronze member',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f5440bbc/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/4514795'},
#   {'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '4520477',
#    'IDSubtitleFile': '1953086744',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '23.976',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': 'DVDRip.XviD-MAXSPEED',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '1',
#    'SubAddDate': '2012-04-17 01:49:39',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '0',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-19bc0c58/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1953086744.gz',
#    'SubDownloadsCnt': '53930',
#    'SubEncoding': 'UTF-8',
#    'SubFeatured': '0',
#    'SubFileName': 'Sherlock Holmes - A Game of Shadows (2011) DVDRip XviD-MAXSPEED.EN.srt',
#    'SubFormat': 'srt',
#    'SubHD': '0',
#    'SubHash': 'ca3321fcc4bcee9e4e7d865dfd818c42',
#    'SubHearingImpaired': '0',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '02:00:00',
#    'SubRating': '9.0',
#    'SubSize': '90645',
#    'SubSumCD': '1',
#    'SubTSGroup': '1',
#    'SubTSGroupHash': 'ee82ed982aebf63a54d7cf0c5f1eccc8',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/4520477/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '1428991',
#    'UserNickName': 'davesimon',
#    'UserRank': 'silver member',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f52e0bb6/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/4520477'},
#   {'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '4521967',
#    'IDSubtitleFile': '1953088305',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '23.976',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': 'Blu-Ray.1080p.AVC.DTS-HD.MA.5.1-HDChina (COLOR Hearing Impaired)',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '1',
#    'SubAddDate': '2012-04-18 23:02:23',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '0',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-19b10c53/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1953088305.gz',
#    'SubDownloadsCnt': '17689',
#    'SubEncoding': 'UTF-8',
#    'SubFeatured': '0',
#    'SubFileName': 'Sherlock.Holmes.A.Game.of.Shadows.2011.1080p.Blu-ray.AVC.DTS-HD.MA.5.1-HDChina.english.srt',
#    'SubFormat': 'srt',
#    'SubHD': '1',
#    'SubHash': 'ecc0d41a3a655ca68da5de65458f37ec',
#    'SubHearingImpaired': '1',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '02:08:40',
#    'SubRating': '0.0',
#    'SubSize': '119542',
#    'SubSumCD': '1',
#    'SubTSGroup': '1',
#    'SubTSGroupHash': 'ee82ed982aebf63a54d7cf0c5f1eccc8',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/4521967/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '847082',
#    'UserNickName': 'cipry',
#    'UserRank': 'trusted',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f53f0bbb/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/4521967'},
#   {'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '4545567',
#    'IDSubtitleFile': '1953111858',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '25.000',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': 'A.Game.of.Shadows.2011.DVDRip.XviD-BiDA',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
# ...
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': '720p.BluRay.x264-SONS',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '1',
#    'SubAddDate': '2012-08-09 23:39:38',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '0',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-19a80c50/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1953183423.gz',
#    'SubDownloadsCnt': '3199',
#    'SubEncoding': 'UTF-8',
#    'SubFeatured': '0',
#    'SubFileName': '720p.BluRay.x264-SONS.srt',
#    'SubFormat': 'srt',
#    'SubHD': '1',
#    'SubHash': '0ca512ca7d6bc4f38edd8bc769eb7792',
#    'SubHearingImpaired': '0',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '02:00:04',
#    'SubRating': '0.0',
#    'SubSize': '90736',
#    'SubSumCD': '1',
#    'SubTSGroup': '1',
#    'SubTSGroupHash': 'ee82ed982aebf63a54d7cf0c5f1eccc8',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/4636089/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '0',
#    'UserNickName': '',
#    'UserRank': '',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f5490bbd/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/4636089'},
#   {'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '4640742',
#    'IDSubtitleFile': '1953188070',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '23.976',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': ' Sherlock Holmes [Part-2][2011] A Game Of Shadows',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '1',
#    'SubAddDate': '2012-08-17 01:10:38',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '0',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-19b70c53/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1953188070.gz',
#    'SubDownloadsCnt': '6666',
#    'SubEncoding': 'UTF-8',
#    'SubFeatured': '0',
#    'SubFileName': 'Sherlock Holmes [Part-2][2011] A Game Of Shadows.srt',
#    'SubFormat': 'srt',
#    'SubHD': '0',
#    'SubHash': 'e407128316740ccef5528fcea64c1c6c',
#    'SubHearingImpaired': '0',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '01:59:59',
#    'SubRating': '0.0',
#    'SubSize': '91045',
#    'SubSumCD': '1',
#    'SubTSGroup': '1',
#    'SubTSGroupHash': 'ee82ed982aebf63a54d7cf0c5f1eccc8',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/4640742/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '0',
#    'UserNickName': '',
#    'UserRank': '',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f53c0bb4/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/4640742'},
#   {'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '4644288',
#    'IDSubtitleFile': '1953191634',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '23.976',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': '720p.BluRay.x264-SONS',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '1',
#    'SubAddDate': '2012-08-22 09:16:10',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '0',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-19ae0c53/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1953191634.gz',
#    'SubDownloadsCnt': '13115',
#    'SubEncoding': 'CP1252',
#    'SubFeatured': '0',
#    'SubFileName': 'sons-sh2-720p.srt',
#    'SubFormat': 'srt',
#    'SubHD': '1',
#    'SubHash': '6467f8448c45aa61e194b65de9957c64',
#    'SubHearingImpaired': '0',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '02:08:40',
#    'SubRating': '0.0',
#    'SubSize': '90325',
#    'SubSumCD': '1',
#    'SubTSGroup': '1',
#    'SubTSGroupHash': 'ee82ed982aebf63a54d7cf0c5f1eccc8',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/4644288/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '67148',
#    'UserNickName': 'Theus',
#    'UserRank': 'trusted',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f54b0bbd/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/4644288'},
#   {'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '5473915',
#    'IDSubtitleFile': '1954067315',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '0.000',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': 'BRRip.XviD.AC3-B89',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '1',
#    'SubAddDate': '2014-01-02 21:58:38',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '0',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-19ac0c52/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1954067315.gz',
#    'SubDownloadsCnt': '1735',
#    'SubEncoding': 'UTF-8',
#    'SubFeatured': '0',
#    'SubFileName': 'Sherlock.Holmes.A.Game.of.Shadows.2011.BRRip.XviD.AC3-B89.srt',
#    'SubFormat': 'srt',
#    'SubHD': '1',
#    'SubHash': '4d40d33001656be0c40e989c23d38cb3',
#    'SubHearingImpaired': '0',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '02:00:05',
#    'SubRating': '0.0',
#    'SubSize': '92686',
#    'SubSumCD': '1',
#    'SubTSGroup': '1',
#    'SubTSGroupHash': 'ee82ed982aebf63a54d7cf0c5f1eccc8',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/5473915/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '0',
#    'UserNickName': '',
#    'UserRank': '',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f5550bbb/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/5473915'},
#   {'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '5989275',
#    'IDSubtitleFile': '1954568330',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '25.000',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': ' Sherlock.Holmes.Game.of.Shadows.2011.480p.BRRip.Xv',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '1',
#    'SubAddDate': '2015-01-04 02:19:07',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '0',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-19cd0c55/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1954568330.gz',
#    'SubDownloadsCnt': '1565',
#    'SubEncoding': 'UTF-8',
#    'SubFeatured': '0',
#    'SubFileName': 'Sherlock.Holmes.Game.of.Shadows.2011.480p.BRRip.Xv-eng.srt',
#    'SubFormat': 'srt',
#    'SubHD': '1',
#    'SubHash': '1ee0990e4b2d25a5223ad1acd5d37e66',
#    'SubHearingImpaired': '0',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '02:00:04',
#    'SubRating': '10.0',
#    'SubSize': '91690',
#    'SubSumCD': '1',
#    'SubTSGroup': '1',
#    'SubTSGroupHash': 'ee82ed982aebf63a54d7cf0c5f1eccc8',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/5989275/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '0',
#    'UserNickName': '',
#    'UserRank': '',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f5870bc6/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/5989275'},
#   {'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '6057448',
#    'IDSubtitleFile': '1954636948',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '25.000',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': ' Sherlock Holmes A Game of Shadows (2011)',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '1',
#    'SubAddDate': '2015-02-25 00:12:07',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '0',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-19d80c60/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1954636948.gz',
#    'SubDownloadsCnt': '2501',
#    'SubEncoding': 'UTF-8',
#    'SubFeatured': '0',
#    'SubFileName': 'Sherlock Holmes A Game of Shadows (2011).srt',
#    'SubFormat': 'srt',
#    'SubHD': '0',
#    'SubHash': 'a37c1215f384c3984afd92d7f24df540',
#    'SubHearingImpaired': '0',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '01:55:24',
#    'SubRating': '0.0',
#    'SubSize': '92789',
#    'SubSumCD': '1',
#    'SubTSGroup': '2',
#    'SubTSGroupHash': '814064fd4437ca5ff2c674d5d6ed70c6',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/6057448/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '634340',
#    'UserNickName': 'Boomie',
#    'UserRank': 'gold member',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f5440bbb/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/6057448'},
#   {'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '6218511',
#    'IDSubtitleFile': '1954799158',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '23.976',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': ' Sherlock.Holmes.A.Game.Of.Shadows.2011.720p.BrRip.x264.YIFY',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '1',
#    'SubAddDate': '2015-06-29 14:40:12',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '0',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-19f20c63/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1954799158.gz',
#    'SubDownloadsCnt': '8434',
#    'SubEncoding': 'CP1252',
#    'SubFeatured': '0',
#    'SubFileName': 'Sherlock.Holmes.A.Game.Of.Shadows.2011.720p.BrRip.x264.YIFY.srt',
#    'SubFormat': 'srt',
#    'SubHD': '1',
#    'SubHash': '0a2a84594b42d7a672ca04cb18db455d',
#    'SubHearingImpaired': '0',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '01:54:29',
#    'SubRating': '1.0',
#    'SubSize': '93165',
#    'SubSumCD': '1',
#    'SubTSGroup': '14',
#    'SubTSGroupHash': '6fbc4e58a9e9e8bdb23f686945e1710c',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/6218511/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '1791052',
#    'UserNickName': 'TommyWelle',
#    'UserRank': 'vip member',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f5360bb1/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/6218511'},
#   {'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '6463504',
#    'IDSubtitleFile': '1955045873',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '0.000',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': 'BDRip.x264.AC3.DUAL-SiSO',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '1',
#    'SubAddDate': '2016-01-16 01:17:11',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '0',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-19ba0c58/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1955045873.gz',
#    'SubDownloadsCnt': '448',
#    'SubEncoding': 'UTF-8',
#    'SubFeatured': '0',
#    'SubFileName': 'Sherlock.Holmes.A.Game.of.Shadows.2011.BDRip.x264.AC3.DUAL-SiSO-eng.srt',
#    'SubFormat': 'srt',
#    'SubHD': '1',
#    'SubHash': 'aa6cfebe4f90a27bdd8314ed4132ee39',
#    'SubHearingImpaired': '0',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '01:59:48',
#    'SubRating': '0.0',
#    'SubSize': '102513',
#    'SubSumCD': '1',
#    'SubTSGroup': '1',
#    'SubTSGroupHash': 'ee82ed982aebf63a54d7cf0c5f1eccc8',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/6463504/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '0',
#    'UserNickName': '',
#    'UserRank': '',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f5480bb5/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/6463504'},
#   {'IDMovie': '54856',
#    'IDMovieImdb': '1515091',
#    'IDSubMovieFile': '0',
#    'IDSubtitle': '6691666',
#    'IDSubtitleFile': '1955271657',
#    'ISO639': 'en',
#    'LanguageName': 'English',
#    'MatchedBy': 'imdbid',
#    'MovieByteSize': '0',
#    'MovieFPS': '25.000',
#    'MovieHash': '0',
#    'MovieImdbRating': '7.5',
#    'MovieKind': 'movie',
#    'MovieName': 'Sherlock Holmes: A Game of Shadows',
#    'MovieNameEng': '',
#    'MovieReleaseName': 'Sherlock Holmes: A Game of Shadows (2011) 720p.BluRay.x264.DTS.RoSubbed-HDChina.Ganool',
#    'MovieTimeMS': '0',
#    'MovieYear': '2011',
#    'QueryNumber': '0',
#    'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'},
#    'SeriesEpisode': '0',
#    'SeriesIMDBParent': '0',
#    'SeriesSeason': '0',
#    'SubActualCD': '1',
#    'SubAddDate': '2016-07-23 05:51:15',
#    'SubAuthorComment': '',
#    'SubBad': '0',
#    'SubComments': '0',
#    'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-19bf0c59/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/filead/1955271657.gz',
#    'SubDownloadsCnt': '1491',
#    'SubEncoding': 'UTF-8',
#    'SubFeatured': '0',
#    'SubFileName': 'Sherlock Holmes II (2011).srt',
#    'SubFormat': 'srt',
#    'SubHD': '1',
#    'SubHash': '257142d0de753c12465c3d13b79c09db',
#    'SubHearingImpaired': '0',
#    'SubLanguageID': 'eng',
#    'SubLastTS': '02:00:00',
#    'SubRating': '0.0',
#    'SubSize': '96336',
#    'SubSumCD': '1',
#    'SubTSGroup': '1',
#    'SubTSGroupHash': 'ee82ed982aebf63a54d7cf0c5f1eccc8',
#    'SubTranslator': '',
#    'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/6691666/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/sherlock-holmes-a-game-of-shadows-en',
#    'UserID': '4008162',
#    'UserNickName': 'LeSaigneur',
#    'UserRank': 'silver member',
#    'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f56c0bc1/sid-nIJo3M2WuBht-Vt2Lsn8e7fsSn0/subad/6691666'}],
#  'seconds': 0.014,
#  'status': '200 OK'}
