# %%
import xmlrpc.client as xrpc

server = xrpc.ServerProxy("http://api.opensubtitles.org/xml-rpc")

# %%
credentials = server.LogIn("omerakgul58", "omeromer", "en", "2016experimentingwithnlp")
# credentials = server.LogIn("randomwalker", "sub1machine", "en", "MachineTitle")

token = credentials.get("token")
info = server.ServerInfo()
info['download_limits']['client_download_quota']

info
# Out:
# {'application': 'OpenSuber v0.2',
#  'contact': 'admin@opensubtitles.org',
#  'download_limits': {'client_24h_download_count': 0,
#   'client_24h_download_limit': 200,
#   'client_download_quota': 200,
#   'client_ip': '5.46.68.58',
#   'global_24h_download_limit': 200,
#   'limit_check_by': 'user_ip'},
#  'last_update_strings': {'ar': '2007-02-03 21:36:14',
#   'at': '2016-02-28 01:41:54',
#   'bg': '2007-02-03 21:36:14',
#   'br': '2016-02-25 05:52:22',
#   'ca': '2014-11-13 11:32:44',
#   'cs': '2014-12-25 01:00:17',
#   'da': '2015-06-16 14:25:51',
#   'de': '2014-11-13 05:01:32',
#   'el': '2015-09-07 11:58:19',
#   'en': '2014-11-12 12:34:41',
#   'eo': '2014-11-13 18:27:49',
#   'es': '2014-11-20 13:11:05',
#   'et': '2014-11-12 16:31:04',
#   'eu': '2014-11-13 17:08:41',
#   'fa': '2007-02-03 21:36:16',
#   'fi': '2014-11-12 13:16:05',
#   'fr': '2014-11-13 08:02:00',
#   'gl': '2007-10-11 16:23:40',
#   'he': '2007-02-03 21:36:17',
#   'hi': '2016-09-08 15:51:39',
#   'hr': '2014-11-13 01:08:44',
#   'hu': '2014-11-13 12:00:33',
#   'hy': '2016-09-15 19:25:10',
#   'id': '2014-11-13 04:42:37',
#   'is': '2014-11-19 00:24:35',
#   'it': '2014-11-12 13:46:33',
#   'ja': '2015-01-20 19:14:48',
#   'ka': '2007-06-09 17:08:29',
#   'km': '2014-11-27 04:29:35',
#   'ko': '2014-12-31 10:02:05',
#   'mk': '2007-12-06 10:45:07',
#   'ms': '2014-12-14 06:37:14',
#   'nl': '2014-11-13 09:33:56',
#   'no': '2014-11-13 09:30:43',
#   'oc': '2008-12-16 12:56:29',
#   'pb': '2014-11-12 17:49:02',
#   'pl': '2014-11-13 14:06:18',
#   'pt': '2014-11-12 22:43:44',
#   'ro': '2014-11-13 09:49:27',
#   'ru': '2014-12-06 11:19:50',
#   'si': '2009-08-09 10:06:20',
#   'sk': '2014-11-25 04:07:58',
#   'sl': '2015-09-01 07:59:50',
#   'sq': '2014-11-13 09:13:12',
#   'sr': '2015-01-17 09:37:01',
#   'sv': '2015-02-13 16:42:39',
#   'th': '2007-06-28 10:37:46',
#   'tl': '2009-08-24 16:32:10',
#   'tr': '2014-11-15 16:38:35',
#   'uk': '2010-03-22 10:14:26',
#   'uz': '2015-11-23 06:17:20',
#   'vi': '2007-02-04 11:05:03',
#   'zh': '2014-11-25 02:32:33',
#   'zt': '2014-11-24 15:11:23'},
#  'movies_aka': '633801',
#  'movies_total': '484458',
#  'seconds': 0.004,
#  'subs_downloads': '4294967295',
#  'subs_subtitle_files': '3928924',
#  'total_subtitles_languages': '75',
#  'users_loggedin': 974,
#  'users_max_alltime': '27449',
#  'users_online_program': 19852,
#  'users_online_total': 23692,
#  'users_registered': '3410270',
#  'website_url': 'http://www.opensubtitles.org',
#  'xmlrpc_url': 'http://api.opensubtitles.org/xml-rpc',
#  'xmlrpc_version': '0.1'}

# %%
# server.GetSubLanguages()
# server.SearchMoviesOnIMDB(token, "troy")
action_imdb_ids = ['1375666', '0120737', '0167260', '0167261', '0944947', '0172495', '0372784', 
                   '0816692', '0076759', '0361748', '0499549', '0080684', '0325980', '0088763', 
                   '0910970', '1392170', '0266543', '0371746', '2015381', '0086190', '1049413', 
                   '0082971', '0110357', '0903624', '0114709', '0107290', '0198781', '2488496', 
                   '1454468', '1392190', '1300854', '0770828', '0435761', '1201607', '0145487', 
                   '0800369', '0120915', '1431045', '1228705', '0383574', '1074638', '0121766', '1270798', '0097576', '1877832', '0458339', '0418279', '0796366', '1843866', '3659388', '1951264', '0090605', '0892769', '2278388', '1170358', '0317705', '0988045', '2395427', '0449088', '0381061', '0126029', '0816711', '0121765', '1446714', '0120903', '0948470', '0241527', '0454876', '1663202', '1631867', '0116629', '0062622', '0758758', '0245429', '0369610', '2294629', '1981115', '0073195', '0316654', '2975590', '0290334', '2802144', '0119654', '0450259', '1408101', '0162222', '0295297', '0330373', '1483013', '1156398', '1323594', '0120363', '0304141', '0413300', '0376994', '0071853', '0332452', '1663662', '0411008', '1298650', '1229238', '2096673', '0458525', '2310332', '0373889', '0319061', '0119116', '0096874', '1840309', '3498820', '1515091', '0407304', '0337978', '0367882', '0319262', '0087469', '0830515', '0926084', '1430132', '0268380', '0478970', '0800080', '0417741', '1399103', '0367594', '1872181', '0120591', '1055369', '2103281', '0120616', '0298148', '0360717', '1951265', '0441773', '1014759', '2193021', '0117060', '0831387', '0112864', '0398286', '0093779', '0032138', '1690953', '0363771', '0099088', '0438488', '2245084', '2379713', '1190080', '0119567', '1542344', '1217209', '0087332', '0092005', '1772341', '1320253', '0096895', '0120912', '0351283', '0120667', '1409024', '0317219', '1104001', '0103639', '0399201', '0111257', '0117500', '0462538', '0317919', '1386697', '1587310', '0368891', '1490017', '0209163', '1764651', '0970179', '0120755', '2109248', '0489099', '0379786', '1403865', '1748122', '2381249', '0348150', '0212720', '0381849', '1453405', '0359950', '0477347', '0472043', '1194173', '0047478', '1735898', '0800320', '1037705', '0190590', '0119698', '1646971', '1133985', '0473075', '0053125', '0120201', '0163025', '1259571', '2948356', '0320661', '0347149', '0190332', '0120669', '0486576', '0413267', '3385516', '0401729', '0120623', '0486655', '0955308', '0429493', '0112384', '0113497', '0411477', '0181875', '1601913', '0104431', '1386703', '1440129', '1959490', '0113189', '0338526', '0438097', '1464540', '0056172', '1092026', '3107288', '1340138', '0112462', '0448134', '0303461', '0099348', '1673434', '0825232', '1638355', '1302011', '1325004', '1192628', '0296572', '0102057', '0465234', '1324999', '1210819', '0120655']

# subtitles = server.SearchSubtitles(token, [ {'imdbid': '1515091', 'sublanguageid': 'eng'} ])
# subtitles = server.SearchSubtitles(token, [ {'imdbid': id, 'sublanguageid': 'eng'} for id in action_imdb_ids[:20]])

# impaired_support = True

# subtitles = list(filter(lambda sub: sub['SubHearingImpaired'] == '1', subtitles))
# print([(sub['SubFormat']) for sub in subtitles['data']])
print(subtitles)
# Out:
# {'data': [{'LanguageName': 'English', 'MovieNameEng': '', 'SeriesIMDBParent': '0', 'MovieKind': 'movie', 'IDSubtitle': '4474095', 'SubActualCD': '1', 'MovieFPS': '25.000', 'SubTSGroupHash': 'd3617a1fc8e35a67ba1b340f295354f1', 'SubLastTS': '01:59:01', 'MovieImdbRating': '7.5', 'SubSumCD': '1', 'IDSubtitleFile': '1953036639', 'SubHash': '2adafc290f91c8825ad6f19fb5edc72d', 'UserNickName': 'Fisticuffs', 'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f5470bba/sid-ksLxPxHWI6oU3ujYTx4qFvwl3ie/sub/4474095', 'SubEncoding': 'UTF-8', 'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'}, 'UserRank': 'bronze member', 'ISO639': 'en', 'MovieByteSize': '0', 'SeriesEpisode': '0', 'SubFeatured': '0', 'IDMovie': '54856', 'MovieHash': '0', 'MovieReleaseName': 'Harks Re-Encode x264 Updated Complete', 'SubFormat': 'srt', 'SubDownloadsCnt': '21305', 'SubTSGroup': '3', 'SubTranslator': '', 'MovieTimeMS': '0', 'MovieName': 'Sherlock Holmes: A Game of Shadows', 'SubAddDate': '2012-02-20 11:21:34', 'SubHearingImpaired': '0', 'SubFileName': 'sherlock holmes II.srt', 'SubRating': '0.0', 'IDMovieImdb': '1515091', 'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/4474095/sid-ksLxPxHWI6oU3ujYTx4qFvwl3ie/sherlock-holmes-a-game-of-shadows-en', 'SubBad': '0', 'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-19a30c56/sid-ksLxPxHWI6oU3ujYTx4qFvwl3ie/file/1953036639.gz', 'SubLanguageID': 'eng', 'SubSize': '102667', 'SubHD': '0', 'SeriesSeason': '0', 'SubComments': '0', 'IDSubMovieFile': '0', 'MatchedBy': 'imdbid', 'MovieYear': '2011', 'SubAuthorComment': '', 'UserID': '1399919', 'QueryNumber': '0'}, {'LanguageName': 'English', 'MovieNameEng': '', 'SeriesIMDBParent': '0', 'MovieKind': 'movie', 'IDSubtitle': '4535061', 'SubActualCD': '1', 'MovieFPS': '23.976', 'SubTSGroupHash': 'ee82ed982aebf63a54d7cf0c5f1eccc8', 'SubLastTS': '02:00:00', 'MovieImdbRating': '7.5', 'SubSumCD': '1', 'IDSubtitleFile': '1953101239', 'SubHash': 'd79b2518cceddf525c0c58d92f4735e7', 'UserNickName': 'deep_sea', 'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f5330bb1/sid-ksLxPxHWI6oU3ujYTx4qFvwl3ie/sub/4535061', 'SubEncoding': 'CP850', 'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'}, 'UserRank': 'trusted', 'ISO639': 'en', 'MovieByteSize': '0', 'SeriesEpisode': '0', 'SubFeatured': '0', 'IDMovie': '54856', 'MovieHash': '0', 'MovieReleaseName': 'BluRay.1080p.DTS.x264-CHD', 'SubFormat': 'srt', 'SubDownloadsCnt': '17884', 'SubTSGroup': '1', 'SubTranslator': '', 'MovieTimeMS': '0', 'MovieName': 'Sherlock Holmes: A Game of Shadows', 'SubAddDate': '2012-04-30 17:28:35', 'SubHearingImpaired': '1', 'SubFileName': 'Sherlock.Holmes.A.Game.of.Shadows.2011.BluRay.1080p.DTS.x264-CHD.eng.srt', 'SubRating': '0.0', 'IDMovieImdb': '1515091', 'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/4535061/sid-ksLxPxHWI6oU3ujYTx4qFvwl3ie/sherlock-holmes-a-game-of-shadows-en', 'SubBad': '0', 'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-197a0c4b/sid-ksLxPxHWI6oU3ujYTx4qFvwl3ie/file/1953101239.gz', 'SubLanguageID': 'eng', 'SubSize': '93636', 'SubHD': '1', 'SeriesSeason': '0', 'SubComments': '0', 'IDSubMovieFile': '0', 'MatchedBy': 'imdbid', 'MovieYear': '2011', 'SubAuthorComment': '', 'UserID': '1295723', 'QueryNumber': '0'}, {'LanguageName': 'English', 'MovieNameEng': '', 'SeriesIMDBParent': '0', 'MovieKind': 'movie', 'IDSubtitle': '4533342', 'SubActualCD': '1', 'MovieFPS': '23.976', 'SubTSGroupHash': 'ee82ed982aebf63a54d7cf0c5f1eccc8', 'SubLastTS': '01:59:59', 'MovieImdbRating': '7.5', 'SubSumCD': '1', 'IDSubtitleFile': '1953099467', 'SubHash': '5718ba7fe09fd8d49cb7df2ffe4f26d8', 'UserNickName': 'spaceboy74', 'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-f5310bb1/sid-ksLxPxHWI6oU3ujYTx4qFvwl3ie/sub/4533342', 'SubEncoding': 'UTF-8', 'QueryParameters': {'imdbid': '1515091', 'sublanguageid': 'eng'}, 'UserRank': 'trusted', 'ISO639': 'en', 'MovieByteSize ...

# %%
# subtitle_ids = [ sub['IDSubtitleFile'] for sub in subtitles]
# result = server.DownloadSubtitles(token, subtitle_ids[:10])

# result = server.DownloadSubtitles(token, ['1953101239'])
result = server.DownloadSubtitles(token, ['66094'])

result
# Out:
# {'data': [{'data': '...',
#    'idsubtitlefile': '66094'}],
#  'seconds': 0.034,
#  'status': '200 OK'}

# %%
# print([res['idsubtitlefile'] for res in result['data']])
# # print(subtitle_ids[:10])


# import base64
# import gzip

# with open("/home/burak/denem.txt", 'w') as file:
#     file.write(gzip.decompress(base64.b64decode(result['data'][0]['data'])).decode())

# %%
# -*- coding: utf-8 -*-
# subtitles_path = "/Users/mesutgurlek/Documents/Machine Learning/project/Movie-Category-Classification-from-Subtitles/Subtitles"
subtitles_path = "/home/burak/Documents/Courses-2016f/CS464/Project/Subtitles"
url_template = "http://www.imdb.com/search/title?genres=%s&explore=genres&sort=num_votes,desc&view=simple"
imdb_page_limit = 1

server = xrpc.ServerProxy("http://api.opensubtitles.org/xml-rpc")
token = server.LogIn("randomwalker", "sub1machine", "en", "MachineTitle").get("token")
remaining_quota = server.ServerInfo()['download_limits']['client_download_quota']

print(server.ServerInfo())

categories = ['action', 'comedy', 'horror', 'war', 'romance', 'adventure']
subtitle_per_category = int(remaining_quota / len(categories))



def parse_movies(imdb_ids=['0172495'], category_name='War'):
        # movie_links = response.css(".bnone").xpath('@href').extract()
        # for link in movie_links:
        #     yield scrapy.Request(url=response.urljoin(link), callback=self.parse_movie)
        print("Listing scraped IMDB ids for%s: ", category_name)
        print(imdb_ids)
        impaired_support = True

        subtitles = {} # key => IDSubtitleFile, value => Metadata of subtitle

        # USING IMDB ID'S, DOWNLOAD THEIR METADATA AND SELECT ID OF A SUITABLE SUBTITLE FOR EACH MOVIE
        for imdb_id in imdb_ids[:subtitle_per_category]:
            print("Searching subtitle for movie with ID: %s" % imdb_id)
            found_subtitles = server.SearchSubtitles(token, [{'imdbid': imdb_id, 'sublanguageid': 'eng'}])['data']

            print("!!!!! Found subtitles: %s" % found_subtitles)

            if impaired_support:
                impaired_subtitles = list(filter(lambda sub: sub['SubHearingImpaired'] == '1', found_subtitles))

            impaired_label = ""
            if len(impaired_subtitles) > 0:
                subtitle = impaired_subtitles[0]
                impaired_label = "(IMPAIRED)"
            else:
                subtitle = found_subtitles[0] # for now get the first subtitle

            filename = "%s/%s/%s %s" % (subtitles_path, category_name, subtitle['MovieName'], impaired_label)

            subtitles[subtitle['IDSubtitleFile']] = {'imdb_id': imdb_id, 'filename': filename,
                                                     'movie_name': subtitle['MovieName'],
                                                    'SubDownloadLink': subtitle['SubDownloadLink']}

            # with open(filename, 'w') as f:
            #     f.write(json.dumps(subtitle['SubDownloadLink']))
            #     # yield parse_movie(imdb_id)


        #DOWNLOAD SUBTITLES AND WRITE THEM INTO FILES
        print("Downloading subtitles of %s" % category_name)
        subtitle_ids = [ idsubtitlefile for idsubtitlefile, val in subtitles.items()]
        subtitle_files_response = server.DownloadSubtitles(token, subtitle_ids)

        import base64
        import gzip

        
        if subtitle_files_response['status'] == '200 OK':
            print("Subtitles downloaded, writing to files...")
            for subtitle_object in subtitle_files_response['data']: #each subtitle_object has base64 data and idsubtitlefile key
                sub = subtitles[subtitle_object['idsubtitlefile']]

                with open(sub['filename'], 'wb') as file:
                    file.write(gzip.decompress(base64.b64decode(subtitle_object['data']))) #.decode())
                    print("Subtitle file saved into: %s" % sub['filename'])


parse_movies()
# Out:
# {'total_subtitles_languages': '75', 'last_update_strings': {'br': '2016-02-25 05:52:22', 'pt': '2014-11-12 22:43:44', 'da': '2015-06-16 14:25:51', 'pb': '2014-11-12 17:49:02', 'is': '2014-11-19 00:24:35', 'fr': '2014-11-13 08:02:00', 'sv': '2015-02-13 16:42:39', 'hr': '2014-11-13 01:08:44', 'fi': '2014-11-12 13:16:05', 'at': '2016-02-28 01:41:54', 'tl': '2009-08-24 16:32:10', 'uk': '2010-03-22 10:14:26', 'de': '2014-11-13 05:01:32', 'no': '2014-11-13 09:30:43', 'eo': '2014-11-13 18:27:49', 'id': '2014-11-13 04:42:37', 'hu': '2014-11-13 12:00:33', 'en': '2014-11-12 12:34:41', 'nl': '2014-11-13 09:33:56', 'eu': '2014-11-13 17:08:41', 'ka': '2007-06-09 17:08:29', 'km': '2014-11-27 04:29:35', 'ms': '2014-12-14 06:37:14', 'vi': '2007-02-04 11:05:03', 'hy': '2016-09-15 19:25:10', 'es': '2014-11-20 13:11:05', 'ja': '2015-01-20 19:14:48', 'ar': '2007-02-03 21:36:14', 'pl': '2014-11-13 14:06:18', 'tr': '2014-11-15 16:38:35', 'si': '2009-08-09 10:06:20', 'it': '2014-11-12 13:46:33', 'uz': '2015-11-23 06:17:20', 'th': '2007-06-28 10:37:46', 'ca': '2014-11-13 11:32:44', 'bg': '2007-02-03 21:36:14', 'oc': '2008-12-16 12:56:29', 'et': '2014-11-12 16:31:04', 'cs': '2014-12-25 01:00:17', 'sl': '2015-09-01 07:59:50', 'ko': '2014-12-31 10:02:05', 'hi': '2016-09-08 15:51:39', 'he': '2007-02-03 21:36:17', 'zh': '2014-11-25 02:32:33', 'zt': '2014-11-24 15:11:23', 'fa': '2007-02-03 21:36:16', 'el': '2015-09-07 11:58:19', 'ro': '2014-11-13 09:49:27', 'sk': '2014-11-25 04:07:58', 'sr': '2015-01-17 09:37:01', 'ru': '2014-12-06 11:19:50', 'gl': '2007-10-11 16:23:40', 'sq': '2014-11-13 09:13:12', 'mk': '2007-12-06 10:45:07'}, 'users_registered': '3399216', 'contact': 'admin@opensubtitles.org', 'users_online_total': 20347, 'xmlrpc_version': '0.1', 'xmlrpc_url': 'http://api.opensubtitles.org/xml-rpc', 'download_limits': {'global_24h_download_limit': 200, 'client_ip': '5.46.12.52', 'limit_check_by': 'user_ip', 'client_24h_download_count': 0, 'client_24h_download_limit': 200, 'client_download_quota': 200}, 'subs_downloads': '4294967295', 'movies_aka': '633416', 'website_url': 'http://www.opensubtitles.org', 'subs_subtitle_files': '3923723', 'application': 'OpenSuber v0.2', 'movies_total': '483444', 'users_max_alltime': '27449', 'users_loggedin': 860, 'users_online_program': 17072, 'seconds': 0.005}
# Listing scraped IMDB ids for%s:  War
# ['0172495']
# Searching subtitle for movie with ID: 0172495
# !!!!! Found subtitles: [{'QueryNumber': '0', 'SeriesIMDBParent': '0', 'IDMovieImdb': '172495', 'SubBad': '0', 'SubTSGroup': '47', 'MovieTimeMS': '0', 'SubAddDate': '2006-03-31 00:00:00', 'MovieNameEng': 'The Gladiators', 'SubHD': '0', 'SubComments': '0', 'MovieReleaseName': 'Gladiator.2000.EE.XviD.AC3.4CD-WAF', 'MovieHash': '0', 'MovieFPS': '0.000', 'QueryParameters': {'imdbid': '0172495', 'sublanguageid': 'eng'}, 'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-e9790b86/sid-s16fsgjzgBJZ9EgcXdDXac19kf7/file/310979.gz', 'MovieName': 'Gladiator', 'SubEncoding': 'ASCII', 'LanguageName': 'English', 'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/235243/sid-s16fsgjzgBJZ9EgcXdDXac19kf7/gladiator-en', 'ISO639': 'en', 'SubFileName': 'Gladiator_2000_EE_ENG_CD2.srt', 'SubActualCD': '2', 'IDMovie': '564', 'SubRating': '8.5', 'IDSubtitle': '235243', 'MovieImdbRating': '8.5', 'SubAuthorComment': '', 'UserNickName': 'andreey (a)', 'SubDownloadsCnt': '1107', 'IDSubtitleFile': '310979', 'UserRank': 'bronze member', 'MovieByteSize': '0', 'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-e9700b7c/sid-s16fsgjzgBJZ9EgcXdDXac19kf7/sub/235243', 'UserID': '64179', 'SeriesEpisode': '0', 'SubHearingImpaired': '0', 'SubSumCD': '4', 'IDSubMovieFile': '0', 'MovieKind': 'movie', 'SeriesSeason': '0', 'SubFeatured': '0', 'MovieYear': '2000', 'SubTSGroupHash': 'adb47a18afde08b19ba4979f429ae45d', 'SubFormat': 'srt', 'SubHash': '98de22a3e9f301345033520e46d46233', 'SubLastTS': '00:42:01', 'SubTranslator': '', 'SubSize': '25008', 'MatchedBy': 'imdbid', 'SubLanguageID': 'eng'}, {'QueryNumber': '0', 'SeriesIMDBParent': '0', 'IDMovieImdb': '172495', 'SubBad': '0', 'SubTSGroup': '48', 'MovieTimeMS': '0', 'SubAddDate': '2006-03-31 00:00:00', 'MovieNameEng': 'The Gladiators', 'SubHD': '0', 'SubComments': '0', 'MovieReleaseName': 'Gladiator.2000.EE.XviD.AC3.4CD-WAF', 'MovieHash': '0', 'MovieFPS': '0.000', 'QueryParameters': {'imdbid': '0172495', 'sublanguageid': 'eng'}, 'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-e9780b85/sid-s16fsgjzgBJZ9EgcXdDXac19kf7/file/310978.gz', 'MovieName': 'Gladiator', 'SubEncoding': 'ASCII', 'LanguageName': 'English', 'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/235243/sid-s16fsgjzgBJZ9EgcXdDXac19kf7/gladiator-en', 'ISO639': 'en', 'SubFileName': 'Gladiator_2000_EE_ENG_CD3.srt', 'SubActualCD': '3', 'IDMovie': '564', 'SubRating': '8.5', 'IDSubtitle': '235243', 'MovieImdbRating': '8.5', 'SubAuthorComment': '', 'UserNickName': 'andreey (a)', 'SubDownloadsCnt': '1107', 'IDSubtitleFile': '310978', 'UserRank': 'bronze member', 'MovieByteSize': '0', 'ZipDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-e9700b7c/sid-s16fsgjzgBJZ9EgcXdDXac19kf7/sub/235243', 'UserID': '64179', 'SeriesEpisode': '0', 'SubHearingImpaired': '0', 'SubSumCD': '4', 'IDSubMovieFile': '0', 'MovieKind': 'movie', 'SeriesSeason': '0', 'SubFeatured': '0', 'MovieYear': '2000', 'SubTSGroupHash': '7beaa6e0cab4019037ec4fec288d7eac', 'SubFormat': 'srt', 'SubHash': '8d4476b3e931b6e2ba9c90414986d43e', 'SubLastTS': '00:42:54', 'SubTranslator': '', 'SubSize': '23822', 'MatchedBy': 'imdbid', 'SubLanguageID': 'eng'}, {'QueryNumber': '0', 'SeriesIMDBParent': '0', 'IDMovieImdb': '172495', 'SubBad': '0', 'SubTSGroup': '13', 'MovieTimeMS': '0', 'SubAddDate': '2006-03-31 00:00:00', 'MovieNameEng': 'The Gladiators', 'SubHD': '0', 'SubComments': '0', 'MovieReleaseName': 'Gladiator.2000.EE.XviD.AC3.4CD-WAF', 'MovieHash': '0', 'MovieFPS': '0.000', 'QueryParameters': {'imdbid': '0172495', 'sublanguageid': 'eng'}, 'SubDownloadLink': 'http://dl.opensubtitles.org/en/download/src-api/vrf-e9770b84/sid-s16fsgjzgBJZ9EgcXdDXac19kf7/file/310977.gz', 'MovieName': 'Gladiator', 'SubEncoding': 'ASCII', 'LanguageName': 'English', 'SubtitlesLink': 'http://www.opensubtitles.org/en/subtitles/235243/sid-s16fsgjzgBJZ9EgcXdDXac19kf7/gladiator-en', 'ISO639': 'en', 'SubFileName': 'Gladiator_2000_EE_ENG_CD1.s ...
# Downloading subtitles of War
# Subtitles downloaded, writing to files...
# Subtitle file saved into: /home/burak/Documents/Courses-2016f/CS464/Project/Subtitles/War/Gladiator (IMPAIRED)
